# %% [markdown]
# Parallel Bars¶
#
# Yul Moldauer
#
# Pommel Horse
#
# Stephen Nedoroscik

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/cleandata22-23/men22_23.csv')

# %%
df['Name']=df['Name'].str.lower()

# %%
df=df.drop(columns=['Location', 'Competition', 'Gender', 'Round'])

# %%
df
# Out:
#               Name Country        Date Apparatus  Rank  D_Score  E_Score  \
# 0      fredrik aas     NOR  2022-02-27        HB  18.0      3.9    8.266
# 1      fredrik aas     NOR  2022-02-27        HB  18.0      3.9    8.266
# 2      fredrik aas     NOR  2022-02-27        PB  23.0      3.9    6.900
# 3      fredrik aas     NOR  2022-02-27        PB  23.0      3.9    6.900
# 4      fredrik aas     NOR  2022-02-27        PH  33.0      4.2    6.666
# ...            ...     ...         ...       ...   ...      ...      ...
# 15128  ahmet önder     TUR  2023-06-04        FX   8.0      4.8    7.050
# 15129  ahmet önder     TUR  2023-06-04        FX   3.0      5.8    7.950
# 15130  ahmet önder     TUR  2023-06-04        HB  10.0      5.0    6.250
# 15131  ahmet önder     TUR  2023-06-04        PB   1.0      6.3    8.050
# 15132  ahmet önder     TUR  2023-06-04        PB   8.0      6.0    7.400
#
#        Penalty   Score  Total_Score
# 0          0.0  12.166       12.166
# ...

# %%
# df['Year'] = df['Date'].str[:4]

# %%
df['Apparatus'].value_counts()
# Out:
# Apparatus
# PH     2558
# FX     2439
# PB     2374
# SR     2319
# HB     2309
# VT1    1654
# VT2     865
# VT      580
# hb       35
# Name: count, dtype: int64

# %%
pb = df[df['Apparatus'] == 'PB']

# %%
pb.head()
# Out:
#            Name Country        Date Apparatus  Rank  D_Score  E_Score  \
# 2   fredrik aas     NOR  2022-02-27        PB  23.0      3.9    6.900
# 3   fredrik aas     NOR  2022-02-27        PB  23.0      3.9    6.900
# 10  fredrik aas     NOR  2023-08-05        PB  54.0      4.4    8.066
# 19  nestor abad     ESP  2022-11-06        PB  12.0      5.8    8.400
# 20  nestor abad     ESP  2022-11-06        PB  26.0      5.8    8.500
#
#     Penalty   Score  Total_Score
# 2       0.0  10.800       10.800
# 3       0.0  10.800       10.800
# 10      0.0  12.466       12.466
# 19      0.0  14.200       14.200
# 20      0.0  14.300       14.300

# %%
pb = df[df['Apparatus'] == 'PB']

# %%
usa_pb=pb[pb['Country']== 'USA']

# %%
yul=pb[pb['Name']== 'yul moldauer']

# %%
yul
# Out:
#               Name Country        Date Apparatus  Rank  D_Score  E_Score  \
# 9413  yul moldauer     USA  2022-08-20        PB   0.0      6.1    7.750
# 9414  yul moldauer     USA  2022-08-20        PB   0.0      6.4    8.300
# 9422  yul moldauer     USA         NaN        PB   5.0      6.1    8.300
# 9426  yul moldauer     USA  2022-02-27        PB   2.0      6.6    7.950
# 9432  yul moldauer     USA  2023-10-08        PB   8.0      6.3    6.833
# 9433  yul moldauer     USA  2023-10-08        PB   4.0      6.6    8.366
# 9434  yul moldauer     USA  2023-10-08        PB   0.0      6.6    8.333
# 9440  yul moldauer     USA  2023-08-06        PB   5.0      6.6    7.950
# 9446  yul moldauer     USA  2023-08-27        PB   0.0      6.6    8.800
# 9447  yul moldauer     USA  2023-08-27        PB   0.0      6.6    8.550
# 9456  yul moldauer     USA  2023-02-26        PB   2.0      6.5    8.300
# 9462  yul moldauer     USA  2023-03-19        PB  10.0      6.5    7.800
#
# ...

# %%
others = usa_pb[usa_pb['Name'] != 'yul moldauer']

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='D_Score', y='E_Score', data=others, color='grey', label='Other Names')
sns.scatterplot(x='D_Score', y='E_Score', data=yul, color='red', label='Yul Moldauer')
plt.title('Scatter Plot of D_Score vs. E_Score for PB (USA)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='D_Score', y='Score', data=others, color='grey', label='Other Names')
sns.scatterplot(x='D_Score', y='Score', data=yul_moldauer_scores, color='red', label='Yul Moldauer')
plt.title('Scatter Plot of D_Score vs. Total for PB (USA)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='E_Score', y='Score', data=others, color='grey', label='Other Names')
sns.scatterplot(x='E_Score', y='Score', data=yul_moldauer_scores, color='red', label='Yul Moldauer')
plt.title('Scatter Plot of E_Score vs. Total for PB (USA)')
plt.legend()
plt.show()

# %%
other0=others[others['Rank']!=0]

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Rank', y='Score', data=other0, color='grey', label='Other Names')
sns.scatterplot(x='Rank', y='Score', data=yul_moldauer_scores, color='red', label='Yul Moldauer')
plt.title('Scatter Plot of E_Score vs. Total for PB (USA)')
plt.legend()
plt.show()

# %%
other=pb[pb['Name']!= 'yul moldauer']

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='D_Score', y='Score', data=other, color='grey', label='Other Names')
sns.scatterplot(x='D_Score', y='Score', data=yul_moldauer_scores, color='red', label='Yul Moldauer')
plt.title('Scatter Plot of D_Score vs. Total for PB (USA)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='E_Score', y='Score', data=other, color='grey', label='Other Names')
sns.scatterplot(x='E_Score', y='Score', data=yul_moldauer_scores, color='red', label='Yul Moldauer')
plt.title('Scatter Plot of E_Score vs. Total for PB (USA)')
plt.legend()
plt.show()

# %%
other2=other[other['Rank']!=0]

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(x='Rank', y='Score', data=other2, color='grey', label='Other Names')
sns.scatterplot(x='Rank', y='Score', data=yul_moldauer_scores, color='red', label='Yul Moldauer')
plt.title('Scatter Plot of E_Score vs. Total for PB (USA)')
plt.legend()
plt.show()

# %%
tops=usa_pb.sort_values(by='Score', ascending=False)

# %%
tops.head(10)
# Out:
#                   Name Country        Date Apparatus  Rank  D_Score  E_Score  \
# 10856  curran phillips     USA  2023-08-27        PB   0.0      6.8     8.75
# 10850  curran phillips     USA  2023-03-12        PB   1.0      6.8     8.70
# 10863  curran phillips     USA  2023-10-25        PB   1.0      6.8     8.60
# 9446      yul moldauer     USA  2023-08-27        PB   0.0      6.6     8.80
# 10861  curran phillips     USA  2023-02-26        PB   1.0      6.8     8.60
# 14253      colt walker     USA  2022-08-20        PB   0.0      6.2     9.15
# 12925        blake sun     USA  2022-08-20        PB   0.0      6.4     8.95
# 10840  curran phillips     USA  2022-08-20        PB   0.0      6.9     8.45
# 10841  curran phillips     USA  2022-08-20        PB   0.0      6.9     8.40
# 14284      colt walker     USA  2023-08-27        PB   0.0      6.0     9.25
#
#        Penalty  Score  Total_Score
# 10856      0.0  15.55        15.55
# 10850      0.0  15.50        15.50
# ...
