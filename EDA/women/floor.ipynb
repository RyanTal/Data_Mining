# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../Combine_Data/women/mult_fx_encoded.csv')

# %%
df
# Out:
#      Rank  D Score  E Score  Pen.   Total  year  medal  Name  nation  round_0  \
# 0     1.0      6.2    8.266   0.0  14.466  2019      1    66      43    False
# 1     2.0      5.6    7.833   0.0  13.433  2019      0    78      22    False
# 2     3.0      5.2    8.100   0.0  13.300  2019      1   126      22    False
# 3     4.0      5.4    7.933  -0.1  13.233  2019      0    94      31    False
# 4     5.0      5.0    8.200   0.0  13.200  2019      0    93      13    False
# ..    ...      ...      ...   ...     ...   ...    ...   ...     ...      ...
# 284  68.0      4.9    6.366   0.0  11.266  2015      0    37      41    False
# 285  70.0      4.4    6.833   0.0  11.233  2015      0   119      29    False
# 286  72.0      3.6    7.500   0.0  11.100  2015      0     8      25    False
# 287  74.0      5.1    6.333  -0.4  11.033  2015      0    45      41    False
# 288  75.0      4.0    6.933   0.0  10.933  2015      0    10       5    False
#
#      round_final  round_qual  tot_final  tot_fin_d  tot_fin_ddiv  \
# 0           True       False     15.466    95.8892   1483.022367
# 1           True       False     14.433    80.8248   1166.544338
# 2           True       False     14.300    74.3600   1063.348000
# 3           True       False     14.233    76.8582   1093.922761
# 4           True       False     14.200    71.0000   1008.200000
# ..           ...         ...        ...        ...           ...
# 284        False        True     11.266    55.2034    621.921504
# 285        False        True     11.233    49.4252    555.193272
# 286        False        True     11.100    39.9600    443.556000
# 287        False        True     11.033    56.2683    620.808154
# 288        False        True     10.933    43.7320    478.121956
#
#      tot_fin_ddiv_rank
# 0          1484.022367
# 1          1168.544338
# 2          1066.348000
# 3          1097.922761
# 4          1013.200000
# ..                 ...
# 284         689.921504
# 285         625.193272
# 286         515.556000
# 287         694.808154
# 288         553.121956
#
# [289 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               289 non-null    float64
#  1   D Score            289 non-null    float64
#  2   E Score            289 non-null    float64
#  3   Pen.               289 non-null    float64
#  4   Total              289 non-null    float64
#  5   year               289 non-null    int64
#  6   medal              289 non-null    int64
#  7   Name               289 non-null    int64
#  8   nation             289 non-null    int64
#  9   round_0            289 non-null    bool
#  10  round_final        289 non-null    bool
#  11  round_qual         289 non-null    bool
#  12  tot_final          289 non-null    float64
#  13  tot_fin_d          289 non-null    float64
#  14  tot_fin_ddiv       289 non-null    float64
#  15  tot_fin_ddiv_rank  289 non-null    float64
# dtypes: bool(3), float64(9), int64(4)
# memory usage: 30.3 KB

# %%
df.describe()
# Out:
#              Rank    D Score     E Score        Pen.       Total         year  \
# count  289.000000  289.00000  289.000000  289.000000  289.000000   289.000000
# mean    12.352941    5.23564    7.779588   -0.064706   12.936682  2016.252595
# std     14.752825    0.60462    0.674113    0.384419    1.220041     2.225609
# min      0.000000    2.00000    4.833000   -6.300000    3.933000  2013.000000
# 25%      3.000000    4.90000    7.466000   -0.100000   12.250000  2015.000000
# 50%      7.000000    5.20000    7.900000    0.000000   12.966000  2015.000000
# 75%     16.000000    5.60000    8.200000    0.000000   13.800000  2019.000000
# max     75.000000    6.80000    9.250000    0.300000   16.050000  2020.000000
#
#             medal        Name      nation   tot_final   tot_fin_d  \
# count  289.000000  289.000000  289.000000  289.000000  289.000000
# mean     0.065744   65.851211   23.273356   13.341526   70.607593
# std      0.248264   38.089195   13.967398    1.492932   15.013153
# min      0.000000    0.000000    0.000000    4.933000    9.866000
# 25%      0.000000   34.000000   12.000000   12.400000   59.455000
# 50%      0.000000   65.000000   22.000000   13.300000   69.779800
# 75%      0.000000   98.000000   35.000000   14.400000   81.213000
# max      1.000000  130.000000   46.000000   17.050000  115.940000
#
#        tot_fin_ddiv  tot_fin_ddiv_rank
# count    289.000000         289.000000
# mean     963.245490         975.598431
# std      303.195341         294.756243
# min       48.668978          56.668978
# 25%      742.150473         754.750000
# 50%      926.694000         935.694000
# 75%     1176.000000        1178.653000
# max     1976.777000        1977.777000

# %%
sns.countplot(x='medal', data=df)
plt.title('Distribution of Medal (Target Variable)')
plt.show()

# %%
df.hist(figsize=(12, 10))
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
selected_features = ['D Score', 'E Score', 'Pen.', 'Total', 'medal']
sns.pairplot(df[selected_features], hue='medal')
plt.show()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Rank                 0
# D Score              0
# E Score              0
# Pen.                 0
# Total                0
# year                 0
# medal                0
# Name                 0
# nation               0
# round_0              0
# round_final          0
# round_qual           0
# tot_final            0
# tot_fin_d            0
# tot_fin_ddiv         0
# tot_fin_ddiv_rank    0
# dtype: int64
