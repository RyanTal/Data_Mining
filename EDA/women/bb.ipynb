# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../Combine_Data/women/bb_encoded.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         587 non-null    float64
#  1   D Score      587 non-null    float64
#  2   E Score      587 non-null    float64
#  3   Pen.         587 non-null    float64
#  4   Total        587 non-null    float64
#  5   year         587 non-null    int64
#  6   medal        587 non-null    int64
#  7   Name         587 non-null    int64
#  8   nation       587 non-null    int64
#  9   round_final  587 non-null    bool
#  10  round_qual   587 non-null    bool
# dtypes: bool(2), float64(5), int64(4)
# memory usage: 42.5 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              Rank     D Score     E Score        Pen.       Total  \
# count  587.000000  587.000000  587.000000  587.000000  587.000000
# mean    27.238501    5.114140    7.107487   -0.038671   12.181934
# std     26.837732    0.621614    1.001535    0.426855    1.507881
# min      1.000000    0.700000    3.900000   -8.000000    1.133000
# 25%      6.000000    4.700000    6.558000    0.000000   11.333000
# 50%     17.000000    5.100000    7.266000    0.000000   12.333000
# 75%     43.500000    5.500000    7.866000    0.000000   13.200000
# max    100.000000    6.500000    8.958000    0.100000   15.358000
#
#               year       medal        Name      nation
# count   587.000000  587.000000  587.000000  587.000000
# mean   2017.873935    0.015332  189.349233   33.040886
# std       2.905999    0.122975  110.181555   17.674388
# min    2013.000000    0.000000    0.000000    0.000000
# 25%    2015.000000    0.000000   94.000000   19.000000
# 50%    2019.000000    0.000000  191.000000   32.000000
# 75%    2021.000000    0.000000  288.000000   49.000000
# max    2021.000000    1.000000  376.000000   62.000000

# %%
sns.countplot(x='medal', data=df)
plt.title('Distribution of Medal (Target Variable)')
plt.show()

# %%
df.hist(figsize=(12, 10))
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
selected_features = ['D Score', 'E Score', 'Pen.', 'Total', 'medal']
sns.pairplot(df[selected_features], hue='medal')
plt.show()
