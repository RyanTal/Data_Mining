# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../Combine_Data/women/vt_encoded.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         145 non-null    float64
#  1   D            145 non-null    float64
#  2   E            145 non-null    float64
#  3   ND           145 non-null    float64
#  4   Total        145 non-null    float64
#  5   D2           145 non-null    float64
#  6   E2           145 non-null    float64
#  7   ND2          145 non-null    float64
#  8   Total2       145 non-null    float64
#  9   Average      145 non-null    float64
#  10  year         145 non-null    float64
#  11  medal        145 non-null    int64
#  12  Name         145 non-null    int64
#  13  Nation       145 non-null    int64
#  14  round_2015   145 non-null    bool
#  15  round_final  145 non-null    bool
# dtypes: bool(2), float64(11), int64(3)
# memory usage: 16.3 KB

# %%
df.describe()
# Out:
#              Rank           D           E          ND       Total          D2  \
# count  145.000000  145.000000  145.000000  145.000000  145.000000  145.000000
# mean     4.303448    5.522069    8.802655   -0.003448   14.292310    4.784828
# std      2.224623    0.554711    0.450155    0.086131    0.766201    1.648372
# min      1.000000    4.300000    7.250000   -0.300000   11.825000    0.000000
# 25%      2.000000    5.000000    8.650000    0.000000   13.850000    4.800000
# 50%      4.000000    5.400000    8.850000    0.000000   14.325000    5.200000
# 75%      6.000000    5.800000    9.066000    0.000000   14.700000    5.600000
# max      8.000000    7.000000    9.766000    0.300000   15.966000    6.400000
#
#                E2         ND2      Total2     Average         year  \
# count  145.000000  145.000000  145.000000  145.000000   145.000000
# mean     7.927345   -0.026207   12.668931   14.056876  2016.075862
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(x='medal', data=df)
plt.title('Distribution of Medal (Target Variable)')
plt.show()

# %%
df.hist(figsize=(12, 10))
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
selected_features = ['D', 'E', 'Rank', 'Average', 'medal']
sns.pairplot(df[selected_features], hue='medal')
plt.show()
