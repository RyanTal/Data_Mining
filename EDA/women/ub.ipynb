# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../Combine_Data/women/ub_encoded.csv')

# %%
df
# Out:
#      Rank  D Score  E Score  Pen.   Total  year  medal  Name  nation  \
# 0     1.0      6.5    8.533   0.0  15.033  2019      1   208       6
# 1     2.0      6.5    8.433   0.0  14.933  2019      0   103      12
# 2     3.0      6.3    8.400   0.0  14.700  2019      0    21      55
# 3     4.0      6.0    8.216   0.0  14.216  2019      0   140      61
# 4     5.0      6.0    8.000   0.0  14.000  2019      0   148      24
# ..    ...      ...      ...   ...     ...   ...    ...   ...     ...
# 441  81.0      1.2    7.566   0.0   8.766  2015      0   196      46
# 442  82.0      2.5    5.700   0.0   8.200  2015      0    26      31
# 443  83.0      3.2    4.600   0.0   7.800  2015      0     6       9
# 444  84.0      3.5    3.933   0.0   7.433  2015      0   164      17
# 445  85.0      3.0    3.800   0.0   6.800  2015      0   108      40
#
#      round_final  round_qual  round_unknown
# 0           True       False          False
# 1           True       False          False
# 2           True       False          False
# 3           True       False          False
# 4           True       False          False
# ..           ...         ...            ...
# 441        False        True          False
# 442        False        True          False
# 443        False        True          False
# 444        False        True          False
# 445        False        True          False
#
# [446 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           446 non-null    float64
#  1   D Score        446 non-null    float64
#  2   E Score        446 non-null    float64
#  3   Pen.           446 non-null    float64
#  4   Total          446 non-null    float64
#  5   year           446 non-null    int64
#  6   medal          446 non-null    int64
#  7   Name           446 non-null    int64
#  8   nation         446 non-null    int64
#  9   round_final    446 non-null    bool
#  10  round_qual     446 non-null    bool
#  11  round_unknown  446 non-null    bool
# dtypes: bool(3), float64(5), int64(4)
# memory usage: 32.8 KB

# %%
df.describe()
# Out:
#              Rank     D Score     E Score        Pen.       Total  \
# count  446.000000  446.000000  446.000000  446.000000  446.000000
# mean    16.627803    5.256278    7.467919   -0.001794   12.723525
# std     18.533433    0.966050    1.043872    0.017646    1.760200
# min      1.000000    1.200000    1.200000   -0.300000    2.500000
# 25%      4.000000    4.800000    6.974500    0.000000   11.700000
# 50%      8.000000    5.400000    7.700000    0.000000   13.000000
# 75%     23.000000    5.900000    8.212000    0.000000   13.966000
# max     85.000000    6.900000    9.250000    0.000000   15.633000
#
#               year       medal        Name      nation
# count   446.000000  446.000000  446.000000  446.000000
# mean   2015.901345    0.038117  137.470852   38.585202
# std       2.121934    0.191693   78.012231   22.203971
# min    2013.000000    0.000000    0.000000    0.000000
# 25%    2015.000000    0.000000   73.000000   21.000000
# 50%    2015.000000    0.000000  137.500000   37.000000
# 75%    2019.000000    0.000000  204.750000   57.000000
# max    2020.000000    1.000000  276.000000   75.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Rank             0
# D Score          0
# E Score          0
# Pen.             0
# Total            0
# year             0
# medal            0
# Name             0
# nation           0
# round_final      0
# round_qual       0
# round_unknown    0
# dtype: int64

# %%
sns.countplot(x='medal', data=df)
plt.title('Distribution of Medal (Target Variable)')
plt.show()

# %%
df.hist(figsize=(12, 10))
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
selected_features = ['D Score', 'E Score', 'Pen.', 'Total', 'medal']
sns.pairplot(df[selected_features], hue='medal')
plt.show()
