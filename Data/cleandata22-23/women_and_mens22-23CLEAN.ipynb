# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_2022_2023.csv')

# %%
df["Competition"].value_counts()
# Out:
# Competition
# 2023 52nd FIG Artistic Gymnastics World Championships         2144
# 2022 51st FIG Artistic Gymnastics World Championships         2078
# 2023 Senior European Championships                            1636
# 2022 Senior European Championships                            1565
# 2023 FISU World University Games                               994
# 2023 Artistic Gymnastics Senior Pan American Championships     885
# SANTIAGO 2023 XIX Pan American Games                           860
# BIRMINGHAM 2022 Commonwealth Games                             691
# 2023 U.S. Championships                                        671
# 2023 Central American and Caribbean Games                      638
# HANGZHOU 2022 19th Asian Games                                 615
# 2023 10th Senior Artistic Gymnastics Asian Championships       601
# 2022 U.S. Championships                                        595
# 2022 British Gymnastics Championships                          583
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24434 entries, 0 to 24433
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LastName     24434 non-null  object
#  1   FirstName    24420 non-null  object
#  2   Gender       24434 non-null  object
#  3   Country      24430 non-null  object
#  4   Date         24434 non-null  object
#  5   Competition  24434 non-null  object
#  6   Round        24434 non-null  object
#  7   Location     24434 non-null  object
#  8   Apparatus    24434 non-null  object
#  9   Rank         21518 non-null  float64
#  10  D_Score      24434 non-null  float64
#  11  E_Score      24434 non-null  float64
#  12  Penalty      4464 non-null   float64
#  13  Score        24434 non-null  float64
# dtypes: float64(5), object(9)
# memory usage: 2.6+ MB

# %%
df["Penalty"] = df["Penalty"].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24434 entries, 0 to 24433
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LastName     24434 non-null  object
#  1   FirstName    24420 non-null  object
#  2   Gender       24434 non-null  object
#  3   Country      24430 non-null  object
#  4   Date         24434 non-null  object
#  5   Competition  24434 non-null  object
#  6   Round        24434 non-null  object
#  7   Location     24434 non-null  object
#  8   Apparatus    24434 non-null  object
#  9   Rank         21518 non-null  float64
#  10  D_Score      24434 non-null  float64
#  11  E_Score      24434 non-null  float64
#  12  Penalty      24434 non-null  float64
#  13  Score        24434 non-null  float64
# dtypes: float64(5), object(9)
# memory usage: 2.6+ MB

# %%
df["Rank"] = df["Rank"].fillna(0)

# %%
df["Country"] = df["Country"].fillna("None")

# %%
df["LastName"] = df["LastName"].fillna("None")
df["FirstName"] = df["FirstName"].fillna("None")
df["D_Score"] = df["D_Score"].fillna(0)
df["E_Score"] = df["E_Score"].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24434 entries, 0 to 24433
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LastName     24434 non-null  object
#  1   FirstName    24434 non-null  object
#  2   Gender       24434 non-null  object
#  3   Country      24434 non-null  object
#  4   Date         24434 non-null  object
#  5   Competition  24434 non-null  object
#  6   Round        24434 non-null  object
#  7   Location     24434 non-null  object
#  8   Apparatus    24434 non-null  object
#  9   Rank         24434 non-null  float64
#  10  D_Score      24434 non-null  float64
#  11  E_Score      24434 non-null  float64
#  12  Penalty      24434 non-null  float64
#  13  Score        24434 non-null  float64
# dtypes: float64(5), object(9)
# memory usage: 2.6+ MB

# %%
df["Total_Score"] = df["D_Score"] + df["E_Score"] - df["Penalty"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24434 entries, 0 to 24433
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LastName     24434 non-null  object
#  1   FirstName    24434 non-null  object
#  2   Gender       24434 non-null  object
#  3   Country      24434 non-null  object
#  4   Date         24434 non-null  object
#  5   Competition  24434 non-null  object
#  6   Round        24434 non-null  object
#  7   Location     24434 non-null  object
#  8   Apparatus    24434 non-null  object
#  9   Rank         24434 non-null  float64
#  10  D_Score      24434 non-null  float64
#  11  E_Score      24434 non-null  float64
#  12  Penalty      24434 non-null  float64
#  13  Score        24434 non-null  float64
#  14  Total_Score  24434 non-null  float64
# dtypes: float64(6), object(9)
# memory usage: 2.8+ MB

# %%
df["Score"] = df["Score"].fillna(0)

# %%
df.isnull().sum()
# Out:
# LastName       0
# FirstName      0
# Gender         0
# Country        0
# Date           0
# Competition    0
# Round          0
# Location       0
# Apparatus      0
# Rank           0
# D_Score        0
# E_Score        0
# Penalty        0
# Score          0
# Total_Score    0
# dtype: int64

# %%
df["Name"] = df["FirstName"] + " " + df["LastName"]

# %%
df = df.drop(columns=["LastName", "FirstName"])

# %%
df["Date"]
# Out:
# 0        24-27 Feb 2022
# 1        24-27 Feb 2022
# 2        24-27 Feb 2022
# 3        23-26 Feb 2023
# 4        23-26 Feb 2023
#               ...
# 24429      1-4 Jun 2023
# 24430      1-4 Jun 2023
# 24431      1-4 Jun 2023
# 24432      1-4 Jun 2023
# 24433      1-4 Jun 2023
# Name: Date, Length: 24434, dtype: object

# %%
df[['Start Date', 'End Date']] = df['Date'].str.split('-', expand=True)

# %%
df = df.drop(columns=["Start Date"])

# %%
df
# Out:
#       Gender Country            Date                        Competition  \
# 0          m     NOR  24-27 Feb 2022             2022 Cottbus World Cup
# 1          m     NOR  24-27 Feb 2022             2022 Cottbus World Cup
# 2          m     NOR  24-27 Feb 2022             2022 Cottbus World Cup
# 3          m     NOR  23-26 Feb 2023             2023 Cottbus World Cup
# 4          m     NOR  23-26 Feb 2023             2023 Cottbus World Cup
# ...      ...     ...             ...                                ...
# 24429      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24430      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24431      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24432      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24433      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
#
#        Round          Location Apparatus  Rank  D_Score  E_Score  Penalty  \
# ...

# %%
# Convert the 'End Date' column to datetime format with automatic format inference
df['End Date'] = pd.to_datetime(df['End Date'], errors='coerce', infer_datetime_format=True)
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_93433/3629933989.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['End Date'] = pd.to_datetime(df['End Date'], errors='coerce', infer_datetime_format=True)

# %%
df
# Out:
#       Gender Country            Date                        Competition  \
# 0          m     NOR  24-27 Feb 2022             2022 Cottbus World Cup
# 1          m     NOR  24-27 Feb 2022             2022 Cottbus World Cup
# 2          m     NOR  24-27 Feb 2022             2022 Cottbus World Cup
# 3          m     NOR  23-26 Feb 2023             2023 Cottbus World Cup
# 4          m     NOR  23-26 Feb 2023             2023 Cottbus World Cup
# ...      ...     ...             ...                                ...
# 24429      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24430      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24431      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24432      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24433      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
#
#        Round          Location Apparatus  Rank  D_Score  E_Score  Penalty  \
# ...

# %%
df["End Date"].value_counts()
# Out:
# End Date
# 2023-10-08    2144
# 2022-11-06    2078
# 2023-04-16    1636
# 2023-05-28    1227
# 2023-08-05     994
# 2022-08-21     905
# 2023-02-26     871
# 2023-10-25     860
# 2022-08-02     691
# 2022-02-27     686
# 2023-08-27     671
# 2022-08-14     660
# 2023-06-28     638
# 2023-09-29     615
# 2022-08-20     595
# 2022-03-27     583
# 2023-08-06     574
# 2023-03-19     564
# 2023-03-12     537
# 2023-03-26     476
# 2023-04-30     461
# 2023-03-04     454
# 2022-04-03     444
# 2022-03-29     413
# 2023-06-11     393
# 2022-03-20     358
# 2022-10-02     321
# 2022-03-05     303
# 2022-10-09     301
# 2023-06-04     269
# 2023-05-06      47
# Name: count, dtype: int64

# %%
df
# Out:
#       Gender Country            Date                        Competition  \
# 0          m     NOR  24-27 Feb 2022             2022 Cottbus World Cup
# 1          m     NOR  24-27 Feb 2022             2022 Cottbus World Cup
# 2          m     NOR  24-27 Feb 2022             2022 Cottbus World Cup
# 3          m     NOR  23-26 Feb 2023             2023 Cottbus World Cup
# 4          m     NOR  23-26 Feb 2023             2023 Cottbus World Cup
# ...      ...     ...             ...                                ...
# 24429      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24430      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24431      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24432      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
# 24433      m     TUR    1-4 Jun 2023  2023 Tel Aviv World Challenge Cup
#
#        Round          Location Apparatus  Rank  D_Score  E_Score  Penalty  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24434 entries, 0 to 24433
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       24434 non-null  object
#  1   Country      24434 non-null  object
#  2   Date         24434 non-null  object
#  3   Competition  24434 non-null  object
#  4   Round        24434 non-null  object
#  5   Location     24434 non-null  object
#  6   Apparatus    24434 non-null  object
#  7   Rank         24434 non-null  float64
#  8   D_Score      24434 non-null  float64
#  9   E_Score      24434 non-null  float64
#  10  Penalty      24434 non-null  float64
#  11  Score        24434 non-null  float64
#  12  Total_Score  24434 non-null  float64
#  13  Name         24434 non-null  object
#  14  End Date     21769 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), object(8)
# memory usage: 2.8+ MB

# %%
df = df.drop(columns=["Date"])

# %%
df.rename(columns={"End Date": "Date"}, inplace=True)

# %%
df
# Out:
#       Gender Country                        Competition  Round  \
# 0          m     NOR             2022 Cottbus World Cup   qual
# 1          m     NOR             2022 Cottbus World Cup   qual
# 2          m     NOR             2022 Cottbus World Cup   qual
# 3          m     NOR             2023 Cottbus World Cup   qual
# 4          m     NOR             2023 Cottbus World Cup   qual
# ...      ...     ...                                ...    ...
# 24429      m     TUR  2023 Tel Aviv World Challenge Cup  final
# 24430      m     TUR  2023 Tel Aviv World Challenge Cup   qual
# 24431      m     TUR  2023 Tel Aviv World Challenge Cup   qual
# 24432      m     TUR  2023 Tel Aviv World Challenge Cup  final
# 24433      m     TUR  2023 Tel Aviv World Challenge Cup   qual
#
#                Location Apparatus  Rank  D_Score  E_Score  Penalty   Score  \
# 0      Cottbus, Germany        HB  18.0      3.9    8.266      0.0  12.166
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Country', 'Competition', 'Round', 'Location', 'Apparatus',
#        'Rank', 'D_Score', 'E_Score', 'Penalty', 'Score', 'Total_Score', 'Name',
#        'Date'],
#       dtype='object')

# %%
# Define the desired column order
desired_order = [ 'Name','Country','Date', 'Gender',  'Competition', 'Round', 'Location', 'Apparatus',
       'Rank', 'D_Score', 'E_Score', 'Penalty', 'Score', 'Total_Score']

# Reorder the columns based on the desired order
df = df[desired_order]

# %%
df
# Out:
#               Name Country       Date Gender  \
# 0      Fredrik AAS     NOR 2022-02-27      m
# 1      Fredrik AAS     NOR 2022-02-27      m
# 2      Fredrik AAS     NOR 2022-02-27      m
# 3      Fredrik AAS     NOR 2023-02-26      m
# 4      Fredrik AAS     NOR 2023-02-26      m
# ...            ...     ...        ...    ...
# 24429  Ahmet ÖNDER     TUR 2023-06-04      m
# 24430  Ahmet ÖNDER     TUR 2023-06-04      m
# 24431  Ahmet ÖNDER     TUR 2023-06-04      m
# 24432  Ahmet ÖNDER     TUR 2023-06-04      m
# 24433  Ahmet ÖNDER     TUR 2023-06-04      m
#
#                              Competition  Round          Location Apparatus  \
# 0                 2022 Cottbus World Cup   qual  Cottbus, Germany        HB
# 1                 2022 Cottbus World Cup   qual  Cottbus, Germany        PB
# 2                 2022 Cottbus World Cup   qual  Cottbus, Germany        PH
# 3                 2023 Cottbus World Cup   qual  Cottbus, Germany        HB
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24434 entries, 0 to 24433
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         24434 non-null  object
#  1   Country      24434 non-null  object
#  2   Date         21769 non-null  datetime64[ns]
#  3   Gender       24434 non-null  object
#  4   Competition  24434 non-null  object
#  5   Round        24434 non-null  object
#  6   Location     24434 non-null  object
#  7   Apparatus    24434 non-null  object
#  8   Rank         24434 non-null  float64
#  9   D_Score      24434 non-null  float64
#  10  E_Score      24434 non-null  float64
#  11  Penalty      24434 non-null  float64
#  12  Score        24434 non-null  float64
#  13  Total_Score  24434 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 2.6+ MB

# %%
df.nunique()
# Out:
# Name           1932
# Country         108
# Date             31
# Gender            2
# Competition      39
# Round             6
# Location         31
# Apparatus        11
# Rank            154
# D_Score          63
# E_Score         331
# Penalty          28
# Score           514
# Total_Score     836
# dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# m    15133
# w     9301
# Name: count, dtype: int64

# %%
women = df[df["Gender"]== "w"]

# %%
women.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9301 entries, 144 to 24416
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         9301 non-null   object
#  1   Country      9301 non-null   object
#  2   Date         8352 non-null   datetime64[ns]
#  3   Gender       9301 non-null   object
#  4   Competition  9301 non-null   object
#  5   Round        9301 non-null   object
#  6   Location     9301 non-null   object
#  7   Apparatus    9301 non-null   object
#  8   Rank         9301 non-null   float64
#  9   D_Score      9301 non-null   float64
#  10  E_Score      9301 non-null   float64
#  11  Penalty      9301 non-null   float64
#  12  Score        9301 non-null   float64
#  13  Total_Score  9301 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 1.1+ MB

# %%
men = df[df["Gender"]== "m"]

# %%
men.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15133 entries, 0 to 24433
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         15133 non-null  object
#  1   Country      15133 non-null  object
#  2   Date         13417 non-null  datetime64[ns]
#  3   Gender       15133 non-null  object
#  4   Competition  15133 non-null  object
#  5   Round        15133 non-null  object
#  6   Location     15133 non-null  object
#  7   Apparatus    15133 non-null  object
#  8   Rank         15133 non-null  float64
#  9   D_Score      15133 non-null  float64
#  10  E_Score      15133 non-null  float64
#  11  Penalty      15133 non-null  float64
#  12  Score        15133 non-null  float64
#  13  Total_Score  15133 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 1.7+ MB

# %%
# men.to_csv("men22_23.csv", index=False)  
# women.to_csv("women22_23.csv", index=False)

# %%
usa=men[men['Country']=='USA']

# %%
usa['Name']=usa['Name'].str.lower()
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_93433/3820000395.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa['Name']=usa['Name'].str.lower()

# %%
usa=usa.drop(columns=['Country', 'Gender', 'Competition', 'Round', 'Location',
                     'Rank', 'Total_Score'])

# %%
usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2366 entries, 390 to 24072
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       2366 non-null   object
#  1   Date       2109 non-null   datetime64[ns]
#  2   Apparatus  2366 non-null   object
#  3   D_Score    2366 non-null   float64
#  4   E_Score    2366 non-null   float64
#  5   Penalty    2366 non-null   float64
#  6   Score      2366 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 147.9+ KB

# %%
usa['year'] = usa['Date'].dt.year

# %%
usa['year'] = usa['year'].fillna(2023).astype(int)

# %%
usa=usa.drop(columns=['Date'])

# %%
usa
# Out:
#                   Name Apparatus  D_Score  E_Score  Penalty  Score  year
# 390     justin ah chow        HB      4.7     7.40      0.0  12.10  2023
# 391     justin ah chow        PB      5.2     7.95      0.0  13.15  2023
# 392     justin ah chow        PH      5.6     6.15      0.0  11.75  2023
# 535    saran alexander        FX      4.5     7.65      0.0  12.15  2023
# 536    saran alexander        HB      3.4     8.35      0.0  11.75  2023
# ...                ...       ...      ...      ...      ...    ...   ...
# 24068  gavin zborowski        HB      4.4     7.55      0.0  11.95  2023
# 24069  gavin zborowski        PB      4.2     8.55      0.0  12.75  2023
# 24070  gavin zborowski        PH      5.0     6.15      0.0  11.15  2023
# 24071  gavin zborowski        SR      4.6     5.40      0.0  10.00  2023
# 24072  gavin zborowski        VT      4.8     8.90      0.0  13.70  2023
#
# [2366 rows x 7 columns]

# %%
average_scores = usa.groupby(['Name', 'Apparatus']).mean().reset_index()

# %%
average_scores= average_scores.drop(columns=['year'])

# %%
usa_men=average_scores.copy()

# %%
# usa_men.to_csv("usa_men22_23.csv", index=False)

# %%
usa_men.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       778 non-null    object
#  1   Apparatus  778 non-null    object
#  2   D_Score    778 non-null    float64
#  3   E_Score    778 non-null    float64
#  4   Penalty    778 non-null    float64
#  5   Score      778 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 36.6+ KB
