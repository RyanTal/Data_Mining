# %%
import pandas as pd
import numpy as np

# %%
wc19melb = pd.read_csv('../../Cleaning/qual_events/men/wc19bmelb_ph.csv')
wc20baku = pd.read_csv('../../Cleaning/qual_events/men/wc20baku_ph.csv')
world18 = pd.read_csv('../../Cleaning/qual_events/men/world18championship_ph.csv')
world19cup = pd.read_csv('../../Cleaning/qual_events/men/world19cup_ph.csv')
wc19bmelb = pd.read_csv('../../Cleaning/qual_events/men/wc19bmelb_ph.csv')

winter20cup = pd.read_csv('../../Cleaning/qual_events/men/winter20cup_ph.csv')

# %%
winter20cup=winter20cup.drop(columns=['Total'])

# %%
winter20cup
# Out:
#     Rank                Athlete    D     E   ND  Score  round  year Nation
# 0      1             alec yoder  6.1  8.60  0.0  14.70  final  2020    USA
# 1      1             alec yoder  6.5  8.80  0.0  15.30  final  2020    USA
# 2      2            allan bower  6.1  8.45  0.0  14.55  final  2020    USA
# 3      2            allan bower  6.1  8.35  0.0  14.45  final  2020    USA
# 4      3            sam mikulak  6.0  8.50  0.0  14.50  final  2020    USA
# 5      3            sam mikulak  6.2  8.15  0.0  14.35  final  2020    USA
# 6      4           yul moldauer  5.6  8.60  0.0  14.20  final  2020    USA
# 7      4           yul moldauer  5.9  8.10  0.0  14.00  final  2020    USA
# 8      5            ian gunther  5.3  8.50  0.0  13.80  final  2020    USA
# 9      5            ian gunther  5.3  8.65  0.0  13.95  final  2020    USA
# 10     6        donothan bailey  6.1  6.90  0.0  13.00  final  2020    USA
# 11     6        donothan bailey  6.2  8.40  0.0  14.60  final  2020    USA
# 12     7            robert neff  6.1  8.05  0.0  14.15  final  2020    USA
# 13     7            robert neff  6.1  6.95  0.0  13.05  final  2020    USA
# 14     8             akash modi  5.5  7.60  0.0  13.10  final  2020    USA
# 15     8             akash modi  5.8  8.25  0.0  14.05  final  2020    USA
# 16     8        nicolas kuebler  4.9  9.00  0.0  13.90  final  2020    USA
# 17     8        nicolas kuebler  4.9  8.35  0.0  13.25  final  2020    USA
# 18    10        brandon briones  5.5  7.80  0.0  13.30  final  2020    USA
# 19    10        brandon briones  5.6  8.10  0.0  13.70  final  2020    USA
# 20    10            sean melton  5.5  8.00  0.0  13.30  final  2020    USA
# 21    10            sean melton  5.4  8.10  0.0  13.50  final  2020    USA
# 22    12           brody malone  5.6  8.35  0.0  13.95  final  2020    USA
# 23    12           brody malone  5.3  7.65  0.0  12.95  final  2020    USA
# 24    13          marvin kimble  6.3  7.75  0.0  14.05  final  2020    USA
# 25    13          marvin kimble  6.0  6.80  0.0  12.80  final  2020    USA
# 26    14            colt walker  5.5  7.60  0.0  13.10  final  2020    USA
# 27    14            colt walker  5.5  7.95  0.0  13.45  final  2020    USA
# 28    14           genko suzuki  5.6  8.25  0.0  13.85  final  2020    USA
# 29    14           genko suzuki  5.9  6.80  0.0  12.70  final  2020    USA
# 30    16              paul juda  4.1  8.55  0.0  12.65  final  2020    USA
# 31    16              paul juda  4.7  9.05  0.0  13.75  final  2020    USA
# 32    17     grant breckenridge  4.6  8.75  0.0  13.35  final  2020    USA
# 33    17     grant breckenridge  4.9  7.70  0.0  12.60  final  2020    USA
# 34    18           cameron bock  5.6  7.45  0.0  13.05  final  2020    USA
# 35    18           cameron bock  5.7  7.15  0.0  12.85  final  2020    USA
# 36    19            matt wenske  4.6  8.45  0.0  13.05  final  2020    USA
# 37    19            matt wenske  4.6  8.10  0.0  12.70  final  2020    USA
# 38    20           timothy wang  6.1  6.50  0.0  12.60  final  2020    USA
# 39    20           timothy wang  6.1  6.75  0.0  12.85  final  2020    USA
# 40    20            kiwan watts  4.8  7.05  0.0  11.85  final  2020    USA
# 41    20            kiwan watts  5.2  8.40  0.0  13.60  final  2020    USA
# 42    22              gage dyer  4.8  7.95  0.0  12.75  final  2020    USA
# 43    22              gage dyer  4.8  7.85  0.0  12.65  final  2020    USA
# 44    23      colin van wicklen  4.8  7.50  0.0  12.30  final  2020    USA
# 45    23      colin van wicklen  4.8  8.25  0.0  13.05  final  2020    USA
# 46    24           isaiah drake  5.1  8.30  0.0  13.40  final  2020    USA
# 47    24           isaiah drake  4.8  6.85  0.0  11.65  final  2020    USA
# 48    25          michael moran  4.9  7.85  0.0  12.75  final  2020    USA
# 49    25          michael moran  4.9  6.60  0.0  11.50  final  2020    USA
# 50    26  adrian de los angeles  5.5  5.30  0.0  10.80  final  2020    USA
# 51    26  adrian de los angeles  5.2  7.70  0.0  12.90  final  2020    USA

# %%
winter20cup['Total']= winter20cup['D'] +  winter20cup['E'] -  winter20cup['ND']

# %%
winter20cup['Total'].max()
# Out:
# 15.3

# %%
ph = pd.concat([wc19melb, wc20baku, world18,world19cup, wc19bmelb])

# %%
ph['Total'].max()
# Out:
# 15.5

# %%
desired_order = ['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'year', 'round']

# Rearrange the columns in-place
winter20cup = winter20cup[desired_order]

# %%
ph = pd.concat([ph, winter20cup])

# %%
ph.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 561 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     561 non-null    int64
#  1   Athlete  561 non-null    object
#  2   Nation   560 non-null    object
#  3   D        561 non-null    float64
#  4   E        561 non-null    float64
#  5   ND       561 non-null    float64
#  6   Total    561 non-null    float64
#  7   year     561 non-null    int64
#  8   round    561 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 43.8+ KB

# %%
ph['Total'].max()
# Out:
# 15.5

# %%
ph.duplicated().sum()
# Out:
# 26

# %%
ph = ph.drop_duplicates()

# %%
# ph.to_csv('ph.csv', index=False)
