# %%
# 282 to 502

# %%
import pandas as pd
import numpy as np

# %%
wc19melb = pd.read_csv('../../Cleaning/qual_events/men/wc19bmelb_hb.csv')
wc20baku = pd.read_csv('../../Cleaning/qual_events/men/wc20baku_hb.csv')
world18 = pd.read_csv('../../Cleaning/qual_events/men/world18championship_hb.csv')
world19cup = pd.read_csv('../../Cleaning/qual_events/men/world19cup_hb.csv')
wc19bmelb = pd.read_csv('../../Cleaning/qual_events/men/wc19bmelb_hb.csv')

winter20cup = pd.read_csv('../../Cleaning/qual_events/men/winter20cup_hb.csv')

# %%
wc19melb.head(1)
# Out:
#    Rank           Athlete Nation    D      E   ND   Total  year  round
# 0     1  hidetaka miyachi    JPN  6.2  8.533  0.0  14.733  2019  final

# %%
wc20baku.head(1)
# Out:
#    Rank         Athlete Nation    D      E   ND   Total  year round
# 0     1  umit samiloglu    TUR  5.7  8.566  0.0  14.266  2020  qual

# %%
world18.head(1)
# Out:
#    Rank          Athlete Nation    D    E   ND  Total  round  year
# 0     1  epke zonderland    NED  6.8  8.3  0.0   15.1  final  2018

# %%
world19cup.head(1)
# Out:
#    Rank         Athlete Nation    D    E   ND  Total  round  year
# 0     1  arthur mariano    BRA  6.3  8.6  0.0   14.9  final  2019

# %%
wc19bmelb.head(1)
# Out:
#    Rank           Athlete Nation    D      E   ND   Total  year  round
# 0     1  hidetaka miyachi    JPN  6.2  8.533  0.0  14.733  2019  final

# %%
winter20cup.head(1)
# Out:
#    Rank            Athlete    D     E   ND  Score  Total  round  year Nation
# 0     1  colin van wicklen  5.6  8.35  0.0  13.95   27.6  final  2020    USA

# %%
desired_order = ['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'year', 'round']

# Rearrange the columns in-place
winter20cup = winter20cup[desired_order]

# %%
hb = pd.concat([wc19melb, wc20baku, world18, world19cup, wc19bmelb, winter20cup])

# %%
hb
# Out:
#     Rank           Athlete Nation    D      E   ND   Total  year  round
# 0      1  hidetaka miyachi    JPN  6.2  8.533  0.0  14.733  2019  final
# 1      2   epke zonderland    NED  6.5  8.233  0.0  14.733  2019  final
# 2      3   zhang chenglong    CHN  6.5  7.833  0.0  14.333  2019  final
# 3      4  mitchell morgans    AUS  6.0  8.033  0.0  14.033  2019  final
# 4      5        tyson bull    AUS  5.8  8.166  0.0  13.966  2019  final
# ..   ...               ...    ...  ...    ...  ...     ...   ...    ...
# 35    18       matt wenske    USA  5.0  7.500  0.0  24.700  2020  final
# 36    19         alex diab    USA  5.1  7.400  0.0  24.600  2020  final
# 37    19         alex diab    USA  4.8  7.300  0.0  24.600  2020  final
# 38    20      cameron bock    USA  4.9  7.550  0.0  24.350  2020  final
# 39    20      cameron bock    USA  5.2  6.700  0.0  24.350  2020  final
#
# [527 rows x 9 columns]

# %%
hb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 527 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     527 non-null    int64
#  1   Athlete  527 non-null    object
#  2   Nation   527 non-null    object
#  3   D        527 non-null    float64
#  4   E        527 non-null    float64
#  5   ND       527 non-null    float64
#  6   Total    527 non-null    float64
#  7   year     527 non-null    int64
#  8   round    527 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 41.2+ KB

# %%
hb.duplicated().sum()
# Out:
# 0

# %%
df = hb.drop_duplicates()

# %%
hb=df.copy()

# %%
hb
# Out:
#     Rank           Athlete Nation    D      E   ND   Total  year  round
# 0      1  hidetaka miyachi    JPN  6.2  8.533  0.0  14.733  2019  final
# 1      2   epke zonderland    NED  6.5  8.233  0.0  14.733  2019  final
# 2      3   zhang chenglong    CHN  6.5  7.833  0.0  14.333  2019  final
# 3      4  mitchell morgans    AUS  6.0  8.033  0.0  14.033  2019  final
# 4      5        tyson bull    AUS  5.8  8.166  0.0  13.966  2019  final
# ..   ...               ...    ...  ...    ...  ...     ...   ...    ...
# 35    18       matt wenske    USA  5.0  7.500  0.0  24.700  2020  final
# 36    19         alex diab    USA  5.1  7.400  0.0  24.600  2020  final
# 37    19         alex diab    USA  4.8  7.300  0.0  24.600  2020  final
# 38    20      cameron bock    USA  4.9  7.550  0.0  24.350  2020  final
# 39    20      cameron bock    USA  5.2  6.700  0.0  24.350  2020  final
#
# [502 rows x 9 columns]

# %%
hb = hb.drop(columns=['Total'])

# %%
hb['Total']=hb['D'] + hb['E'] - hb['ND']

# %%
hb['Total'].max()
# Out:
# 15.100000000000001

# %%
hb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 502 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     502 non-null    int64
#  1   Athlete  502 non-null    object
#  2   Nation   502 non-null    object
#  3   D        502 non-null    float64
#  4   E        502 non-null    float64
#  5   ND       502 non-null    float64
#  6   year     502 non-null    int64
#  7   round    502 non-null    object
#  8   Total    502 non-null    float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 39.2+ KB

# %%
# hb.to_csv('hb.csv', index=False)
