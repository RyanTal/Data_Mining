# %%
# Welcome to the CBC MILP Solver 
# Version: Trunk
# Build Date: Oct 28 2021 

# Starting solution of the Linear programming relaxation problem using Primal Simplex

# The problem does not have an optimal solution.

# %%
# from ortools.linear_solver import pywraplp
# The problem does not have an optimal solution.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('usa_men.csv')

# %%
dfs = pd.read_csv('../../Data/cleandata22-23/usa_men22_23.csv')

# %%
dfs
# Out:
#                         Name Apparatus  D_Score  E_Score  Penalty    Score
# 0    adriel perales-valencia        PB    5.200   8.7000    0.000  13.9000
# 1    adriel perales-valencia        SR    5.400   7.4500    0.000  12.8500
# 2                  aidan cuy        FX    4.700   8.2000    0.000  12.9000
# 3                  aidan cuy        HB    4.000   7.6500    0.000  11.6500
# 4                  aidan cuy        PB    4.800   8.1500    0.000  12.9500
# ..                       ...       ...      ...      ...      ...      ...
# 770            zachary nunez        HB    4.500   8.6500    0.000  13.1500
# 771            zachary nunez        PB    5.125   8.1125    0.000  13.2375
# 772            zachary nunez        PH    5.650   7.6250    0.000  13.2750
# 773            zachary nunez        SR    4.700   8.2500    0.000  12.9500
# 774            zachary nunez        VT    5.100   8.5375    0.025  13.6125
#
# [775 rows x 6 columns]

# %%
df2=df.copy()

# %%
# Asher Hong
# Fred Richard
# Khoi Young
# Vitaliy Guimaraes
# Yul Moldauer

# %%
selected_athletes = ['asher hong', 'fred richard', 'khoi young', 
                     'vitaliy guimaraes', 'yul moldauer']

# Filter DataFrame based on the list of athletes
filtered_df = df[df['Athlete'].isin(selected_athletes)]

# %%
df = filtered_df.copy()

# %%
df.iloc[4:5]
# Out:
#    Unnamed: 0  Rank       Athlete    FX      PH      SR     VT      PB    HB  \
# 9         679   1.0  yul moldauer  14.4  13.957  14.114  14.25  15.121  13.5
#
#        AA
# 9  85.342

# %%
df
# Out:
#     Unnamed: 0  Rank            Athlete      FX      PH      SR      VT  \
# 0          421   1.0  vitaliy guimaraes  14.250  14.350  13.600  14.450
# 1          422   2.0         khoi young  13.550  15.342  12.550  15.244
# 2          423   3.0         asher hong  14.029  12.949  14.566  16.680
# 3          424   4.0       yul moldauer  13.400  13.789  14.116  13.400
# 9          679   1.0       yul moldauer  14.400  13.957  14.114  14.250
# 10         680   2.0       fred richard  14.483  13.357  13.350  14.000
# 11         681   3.0         asher hong  12.203  12.507  14.133  14.755
#
#         PB      HB      AA
# 0   13.900  13.400  83.950
# 1   13.750  13.100  83.536
# 2   14.355  10.450  83.029
# 3   15.543  11.400  81.648
# 9   15.121  13.500  85.342
# 10  14.450  14.962  84.602
# 11  14.700  13.650  81.948

# %%
sorted_df = df.sort_values(by='AA', ascending=False)

# %%
df=sorted_df.copy()

# %%
df = df.iloc[0:5]

# %%
df=df.drop(columns=['Unnamed: 0', 'Rank'])

# %%
df= df.drop(columns=['AA'])

# %%
import pandas as pd
from itertools import combinations
import pandas as pd
from pyqubo import Array, Constraint, Placeholder, solve_qubo
from itertools import combinations

# %%
from pymoo.operators.crossover.sbx import SBX
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.util import plotting

from pymoo.core.population import Population
from pymoo.core.problem import Problem
from pymoo.operators.mutation.pm import PolynomialMutation
import pandas as pd
from pyqubo import Array, Placeholder, Constraint
from pymoo.core.problem import Problem
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.operators.crossover.sbx import SBX
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.operators.repair.rounding import RoundingRepair
from pymoo.optimize import minimize

# %%
import pandas as pd
from pyqubo import Array, Constraint, Placeholder, solve_qubo
from itertools import combinations
from ortools.sat.python import cp_model

# %%
import pandas as pd
import networkx as nx
from networkx.algorithms import bipartite
from scipy.optimize import linear_sum_assignment

# %%
df
# Out:
#               Athlete      FX      PH      SR      VT      PB      HB
# 9        yul moldauer  14.400  13.957  14.114  14.250  15.121  13.500
# 10       fred richard  14.483  13.357  13.350  14.000  14.450  14.962
# 0   vitaliy guimaraes  14.250  14.350  13.600  14.450  13.900  13.400
# 1          khoi young  13.550  15.342  12.550  15.244  13.750  13.100
# 2          asher hong  14.029  12.949  14.566  16.680  14.355  10.450

# %%
# import pandas as pd
# import networkx as nx
# from networkx.algorithms import bipartite



# # Create a bipartite graph
# B = nx.Graph()
# B.add_nodes_from(df['Athlete'], bipartite=0)
# B.add_nodes_from(df.columns[1:-1], bipartite=1)

# # Add weighted edges
# for i, row in df.iterrows():
#     for j in range(1, len(df.columns)-1):
#         B.add_edge(row['Athlete'], df.columns[j], weight=row[df.columns[j]])

# # Solve the weighted bipartite matching problem
# matching = bipartite.maximum_matching(B)

# # Extract the selected athletes and their corresponding apparatus
# selected_athletes = {athlete: apparatus for athlete, apparatus in matching.items() if isinstance(apparatus, str)}

# # Print the selected athletes and their corresponding apparatus
# for athlete, apparatus in selected_athletes.items():
#     print(f"{athlete} will compete on {apparatus}")

# %%
# data = {
#     'Athlete': ['khoi young', 'fred richard', 'yul moldauer', 'vitaliy guimaraes', 
#                 'asher hong','vitaliy guimaraes', 'asher hong', 'fred richard',
#                 'yul moldauer', 'khoi young'],
#     'Apparatus': ['FX', 'PH', 'SR', 'VT', 'PB', 'VT', 'PB', 'PH', 'SR', 'FX' ]
# }

# df = pd.DataFrame(data)

# %%
# df['Apparatus'].value_counts()

# %%
# df['Athlete'].value_counts()

# %%
df
# Out:
#               Athlete      FX      PH      SR      VT      PB      HB
# 9        yul moldauer  14.400  13.957  14.114  14.250  15.121  13.500
# 10       fred richard  14.483  13.357  13.350  14.000  14.450  14.962
# 0   vitaliy guimaraes  14.250  14.350  13.600  14.450  13.900  13.400
# 1          khoi young  13.550  15.342  12.550  15.244  13.750  13.100
# 2          asher hong  14.029  12.949  14.566  16.680  14.355  10.450

# %%
import pandas as pd
from pulp import LpProblem, LpVariable, lpSum, LpMaximize

# Sample DataFrame
data = {
    'Athlete': ['yul moldauer', 'fred richard', 'vitaliy guimaraes', 'khoi young', 'asher hong'],
    'FX': [14.400, 14.483, 14.250, 13.550, 14.029],
    'PH': [13.957, 13.357, 14.350, 15.342, 12.949],
    'SR': [14.114, 13.350, 13.600, 12.550, 14.566],
    'VT': [14.250, 14.000, 14.450, 15.244, 16.680],
    'PB': [15.121, 14.450, 13.900, 13.750, 14.355],
    'HB': [13.500, 14.962, 13.400, 13.100, 10.450],
}

df = pd.DataFrame(data)

# Number of athletes and apparatus
num_athletes = len(df)
num_apparatus = len(df.columns) - 1  # Exclude 'Athlete' column

# Binary decision variables
athlete_vars = {athlete: LpVariable(f'athlete_{athlete}', cat='Binary') for athlete in df['Athlete']}
apparatus_vars = {apparatus: LpVariable(f'apparatus_{apparatus}', cat='Binary') for apparatus in df.columns[1:]}

# Continuous decision variables for scores
score_vars = {(athlete, apparatus): LpVariable(f'score_{athlete}_{apparatus}', cat='Binary')
              for athlete in df['Athlete'] for apparatus in df.columns[1:]}

# Create the optimization problem
prob = LpProblem("Athlete_Apparatus_Assignment", LpMaximize)

# Objective function: maximize the total AA score
prob += lpSum(df.loc[i, apparatus] * score_vars[df['Athlete'][i], apparatus]
              for i in range(num_athletes) for apparatus in df.columns[1:]), "Total_Score"

# Constraints: each athlete competes on each apparatus exactly 3 times
for i in range(num_athletes):
    for apparatus in df.columns[1:]:
        prob += lpSum(score_vars[df['Athlete'][i], app] for app in df.columns[1:]) == 3 * athlete_vars[df['Athlete'][i]]

# Constraints: each apparatus is competed on exactly 3 times
for apparatus in df.columns[1:]:
    prob += lpSum(athlete_vars[athlete] for athlete in df['Athlete']) == 4, f'Apparatus_{apparatus}_constraint'

# Solve the problem
prob.solve()

# Extract the selected athletes and their corresponding apparatus
selected_athletes = [athlete for athlete, var in athlete_vars.items() if var.value() == 1]
selected_apparatus = [apparatus for apparatus, var in apparatus_vars.items() if var.value() == 1]



    
# Print the selected athletes and their corresponding apparatus
for athlete in selected_athletes:
    athlete_apparatus = [apparatus for apparatus in df.columns[1:] if score_vars[athlete, apparatus].value() == 1]
    print(f"{athlete} will compete on {', '.join(athlete_apparatus)}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/bfa7ffc1909149e48f090a025062750c-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/bfa7ffc1909149e48f090a025062750c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 41 COLUMNS
# At line 382 RHS
# At line 419 BOUNDS
# At line 455 ENDATA
# Problem MODEL has 36 rows, 35 columns and 240 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 178.403 - 0.00 seconds
# Cgl0004I processed model has 6 rows, 35 columns (35 integer (35 of which binary)) and 40 elements
# Cutoff increment increased from 1e-05 to 0.000999
# Cbc0038I Initial state - 3 integers unsatisfied sum - 1
# ...

# %%
df

# %%
df2=df2.drop(columns=['Unnamed: 0', 'Rank'])

# %%
df_sorted = df2.sort_values(by='AA', ascending=False)

# %%
df_sorted

# %%
df_unique = df_sorted.drop_duplicates(subset='Athlete', keep='first')

# %%
dfs = df_unique.copy()

# %%
dfs=dfs.drop(columns=['AA'])

# %%
dfs

# %%
data = {
    'Athlete': ['yul moldauer', 'fred richard', 
                'khoi young', 'asher hong'],
    'Apparatus1': ['FX', 'FX', 'PH', 'SR', ],
    'Apparatus2': ['VT', 'PB', 'VT', 'VT', ],
    'Apparatus3': ['PB', 'HB', 'PB', 'PB', ]
}
df = pd.DataFrame(data)

# %%
df['Apparatus1'].value_counts()

# %%
df['Apparatus2'].value_counts()

# %%
df['Apparatus3'].value_counts()

# %%
# VT = 3
#pb = 4
#hb=1
#fx=2
#

# %%
# use python, pandas, PyQUBO, pymoo, itertools , OR-Tools ,  etc
# write algorithm code for cominatoral maximization for followin df to find 4 athletes thwt will compete . each apparatus needs to be competeed on 3 timres and a athlete can not compete on the same apparartus more than once. the goal is to gi the largest sum from using each appartus 3 times between 4 athletes

# Athlete 	FX 	PH 	SR 	VT 	PB 	HB 	AA
# 9 	yul moldauer 	14.400 	13.957 	14.114 	14.250 	15.121 	13.500 	85.342
# 10 	fred richard 	14.483 	13.357 	13.350 	14.000 	14.450 	14.962 	84.602
# 0 	vitaliy guimaraes 	14.250 	14.350 	13.600 	14.450 	13.900 	13.400 	83.950
# 1 	khoi young 	13.550 	15.342 	12.550 	15.244 	13.750 	13.100 	83.536
# 2 	asher hong 	14.029 	12.949 	14.566 	16.680 	14.355 	10.450 	83.029

# %%
import sys
sys.path

# %%
# /Users/ryantalbot/opt/anaconda3/envs/tf2/bin/python3 -m pip install pymoo

# %%
# use python, pandas, PyQUBO, pymoo, itertools , OR-Tools ,  etc
# write algorithm code for cominatoral maximization for followin df to find 4 athletes thwt will compete . each apparatus needs to be competeed on 3 timres and a athlete can not compete on the same apparartus more than once. the goal is to gi the largest sum from using each appartus 3 times between 4 athletes

# Athlete 	FX 	PH 	SR 	VT 	PB 	HB 	AA
# 9 	yul moldauer 	14.400 	13.957 	14.114 	14.250 	15.121 	13.500 	85.342
# 10 	fred richard 	14.483 	13.357 	13.350 	14.000 	14.450 	14.962 	84.602
# 0 	vitaliy guimaraes 	14.250 	14.350 	13.600 	14.450 	13.900 	13.400 	83.950
# 1 	khoi young 	13.550 	15.342 	12.550 	15.244 	13.750 	13.100 	83.536
# 2 	asher hong 	14.029 	12.949 	14.566 	16.680 	14.355 	10.450 	83.029

# %%
from pulp import LpProblem, LpVariable, lpSum, value, LpMaximize

# %%
dfs = pd.read_csv('../../Data/cleandata22-23/usa_men22_23.csv')

# %%
df=dfs.copy()

# %%
# # Create a binary variable for each combination of athlete and apparatus
# athletes = df['Name'].unique()
# apparatus = df['Apparatus'].unique()

# x = LpVariable.dicts('x', [(athlete, app) for athlete in athletes for app in apparatus], 0, 1, LpMaximize)

# # Create the LP problem
# model = LpProblem("Athlete_Selection", LpMaximize)

# # Define the objective function
# model += lpSum(df['Score'][i] * x[df['Name'][i], df['Apparatus'][i]] for i in range(len(df)))

# # Define the constraints
# for athlete in athletes:
#     model += lpSum(x[athlete, app] for app in apparatus) >= 1  # Each athlete competes on exactly 3 apparatus

# for app in apparatus:
#     model += lpSum(x[athlete, app] for athlete in athletes) == 3  # Each apparatus is used exactly 3 times


# model += lpSum(x[athlete, app] for athlete in athletes) == 4  # Select exactly 4 athletes


# # Solve the problem
# model.solve()

# # Check if the optimization problem has a feasible solution
# if model.status == 1:  # 1 indicates an optimal solution
#     # Extract the results
#     selected_athletes = [athlete for athlete in athletes if any(value(x[athlete, app]) > 0.9 for app in apparatus)]
#     total_score = sum(df.loc[(df['Name'] == athlete) & (df['Apparatus'] == app), 'Score'].values[0] for athlete in selected_athletes for app in apparatus)

#     # Display the results
#     print(f"Selected Athletes: {selected_athletes}")
#     print(f"Total Score: {total_score}")
# else:
#     print("No feasible solution found.")

# %%
df
# Out:
#                         Name Apparatus  D_Score  E_Score  Penalty    Score
# 0    adriel perales-valencia        PB    5.200   8.7000    0.000  13.9000
# 1    adriel perales-valencia        SR    5.400   7.4500    0.000  12.8500
# 2                  aidan cuy        FX    4.700   8.2000    0.000  12.9000
# 3                  aidan cuy        HB    4.000   7.6500    0.000  11.6500
# 4                  aidan cuy        PB    4.800   8.1500    0.000  12.9500
# ..                       ...       ...      ...      ...      ...      ...
# 770            zachary nunez        HB    4.500   8.6500    0.000  13.1500
# 771            zachary nunez        PB    5.125   8.1125    0.000  13.2375
# 772            zachary nunez        PH    5.650   7.6250    0.000  13.2750
# 773            zachary nunez        SR    4.700   8.2500    0.000  12.9500
# 774            zachary nunez        VT    5.100   8.5375    0.025  13.6125
#
# [775 rows x 6 columns]

# %%
# from pulp import LpVariable, lpSum, LpProblem, LpMaximize, LpStatus

# # Create a binary variable for each combination of athlete and apparatus
# athletes = df['Name'].unique()
# apparatus = df['Apparatus'].unique()

# # Create the LP problem
# model = LpProblem("Athlete_Selection", LpMaximize)

# # Create binary decision variables
# x = LpVariable.dicts('x', [(athlete, app) for athlete in athletes for app in apparatus], 0, 1, LpMaximize)

# # Define the objective function
# model += lpSum(df['Score'][i] * x[df['Name'][i], df['Apparatus'][i]] for i in range(len(df)))

# # Define the constraints
# for athlete in athletes:
#     model += lpSum(x[athlete, app] for app in apparatus) >= 1  # Each athlete competes on at least 1 apparatus

# for app in apparatus:
#     model += lpSum(x[athlete, app] for athlete in athletes) == 3  # Each apparatus is used exactly 3 times

# model += lpSum(x[athlete, app] for athlete in athletes for app in apparatus) == 4  # Select exactly 4 athletes

# model.solve()

# # Check if the optimization problem has a feasible solution
# if LpStatus[model.status] == 'Infeasible':
#     print("No feasible solution found.")
# else:
#     # Extract the results
#     selected_athletes = [athlete for athlete in athletes if any(x[athlete, app].value() > 0.9 for app in apparatus)]

#     total_score = sum(df.loc[(df['Name'] == athlete) & (df['Apparatus'] == app), 'Score'].values[0] for athlete in selected_athletes for app in apparatus)

#     # Display the results
#     print(f"Selected Athletes: {selected_athletes}")
#     print(f"Total Score: {total_score}")

# %%
df
# Out:
#                         Name Apparatus  D_Score  E_Score  Penalty    Score
# 0    adriel perales-valencia        PB    5.200   8.7000    0.000  13.9000
# 1    adriel perales-valencia        SR    5.400   7.4500    0.000  12.8500
# 2                  aidan cuy        FX    4.700   8.2000    0.000  12.9000
# 3                  aidan cuy        HB    4.000   7.6500    0.000  11.6500
# 4                  aidan cuy        PB    4.800   8.1500    0.000  12.9500
# ..                       ...       ...      ...      ...      ...      ...
# 770            zachary nunez        HB    4.500   8.6500    0.000  13.1500
# 771            zachary nunez        PB    5.125   8.1125    0.000  13.2375
# 772            zachary nunez        PH    5.650   7.6250    0.000  13.2750
# 773            zachary nunez        SR    4.700   8.2500    0.000  12.9500
# 774            zachary nunez        VT    5.100   8.5375    0.025  13.6125
#
# [775 rows x 6 columns]

# %%
selected_names = ['yul moldauer', 'fred richard', 'vitaliy guimaraes', 'khoi young', 'asher hong']
filtered_df = df[df['Name'].isin(selected_names)]

# %%
df = filtered_df.copy()

# %%
df
# Out:
#                   Name Apparatus   D_Score   E_Score   Penalty      Score
# 49          asher hong        FX  6.035714  7.997429  0.121429  13.911714
# 50          asher hong        HB  5.200000  7.006917  0.000000  12.206917
# 51          asher hong        PB  6.000000  8.609867  0.000000  14.609867
# 52          asher hong        PH  5.664286  7.463000  0.000000  13.127286
# 53          asher hong        SR  5.966667  8.182067  0.000000  14.148733
# 54          asher hong        VT  6.000000  8.705909  0.100000  14.605909
# 55          asher hong       VT1  6.000000  8.669000  0.116667  14.552333
# 56          asher hong       VT2  5.400000  8.716250  0.050000  14.066250
# 269       fred richard        FX  5.975000  7.650000  0.075000  13.550000
# 270       fred richard        HB  5.960000  7.480000  0.000000  13.440000
# 271       fred richard        PB  5.780000  8.260000  0.000000  14.040000
# 272       fred richard        PH  5.960000  6.690000  0.000000  12.650000
# ...

# %%
from pulp import LpVariable, LpProblem, lpSum, LpMinimize, GLPK


# Create a binary variable for each combination of athlete and apparatus
athletes = df['Name'].unique()
apparatus = df['Apparatus'].unique()

# Create the LP problem
model = LpProblem("Athlete_Selection", LpMaximize)

# Create binary decision variables
x = LpVariable.dicts('x', [(athlete, app) for athlete in athletes for app in apparatus], 0, 1, LpMaximize)

# Define the objective function
model += lpSum(df.loc[(df['Name'] == athlete) & (df['Apparatus'] == app), 'Score'].values[0] * x[athlete, app] for athlete in athletes for app in apparatus if not df.loc[(df['Name'] == athlete) & (df['Apparatus'] == app)].empty)

# Define the constraints
for athlete in athletes:
    model += lpSum(x[athlete, app] for app in apparatus) >= 1  # Each athlete competes on at least 1 apparatus

for app in apparatus:
    model += lpSum(x[athlete, app] for athlete in athletes) == 3  # Each apparatus is used exactly 3 times

model += lpSum(x[athlete, app] for athlete in athletes for app in apparatus) == 4  # Select exactly 4 athletes

# Solve the problem
model.solve()

# Check if the optimization problem has a feasible solution
if LpStatus[model.status] == 'Infeasible':
    print("No feasible solution found.")
else:
    # Extract the results
    selected_athletes = [athlete for athlete in athletes if any(x[athlete, app].value() > 0.9 for app in apparatus)]
    total_score = sum(df.loc[(df['Name'] == athlete) & (df['Apparatus'] == app), 'Score'].values[0] for athlete in selected_athletes for app in apparatus if not df.loc[(df['Name'] == athlete) & (df['Apparatus'] == app)].empty)

    # Display the results
    print(f"Selected Athletes: {selected_athletes}")
    print(f"Total Score: {total_score}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/712467e888eb49a5ad89e48c67c8861e-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/712467e888eb49a5ad89e48c67c8861e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 19 COLUMNS
# At line 175 RHS
# At line 190 BOUNDS
# At line 231 ENDATA
# Problem MODEL has 14 rows, 40 columns and 120 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 0  Obj -0 Primal inf 32.999999 (14) Dual inf 485.27603 (35)
# 4  Obj 51.794852 Primal inf 28.999999 (8)
# ...

# %%
from pulp import LpVariable, LpProblem, lpSum, LpMinimize, GLPK

data = df.copy()

# Extract unique athletes and apparatus
athletes = set(data['Name'])
apparatus = set(data['Apparatus'])

# Create LP problem
model = LpProblem("Athlete_Score_Optimization", LpMinimize)

# Create binary decision variables
x = LpVariable.dicts('x', ((athlete, app) for athlete in athletes for app in apparatus), cat='Binary')

# Define the objective function
model += lpSum(data.loc[(data['Name'] == athlete) & (data['Apparatus'] == app), 'Score'].values[0] * x[athlete, app]
              for athlete in athletes for app in apparatus
              if not data.loc[(data['Name'] == athlete) & (data['Apparatus'] == app)].empty)

# Define the constraints
for athlete in athletes:
    model += lpSum(x[athlete, app] for app in apparatus) >= 1  # Each athlete competes on at least 1 apparatus

for app in apparatus:
    model += lpSum(x[athlete, app] for athlete in athletes) >= 1  # Each apparatus is used at least once



# Solve the problem using GLPK solver
model.solve(GLPK(path='/usr/local/bin/glpsol', msg=True))

print("Solver Status:", LpStatus[model.status])

# Extract the results
selected_athletes = [athlete for athlete in athletes if any(x[athlete, app].value() > 0.9 for app in apparatus)]

# Display the results
print(f"Selected Athletes: {selected_athletes}")
print("Optimal Score:", model.objective.value())
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ab66ef9eec02475f8e5522ae7d0585cf-pulp.lp
#  -o /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ab66ef9eec02475f8e5522ae7d0585cf-pulp.sol
# Reading problem data from '/var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ab66ef9eec02475f8e5522ae7d0585cf-pulp.lp'...
# 14 rows, 40 columns, 120 non-zeros
# 40 integer variables, all of which are binary
# 124 lines were read
# GLPK Integer Optimizer 5.0
# 14 rows, 40 columns, 120 non-zeros
# 40 integer variables, all of which are binary
# Preprocessing...
# 14 rows, 40 columns, 120 non-zeros
# 40 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 14
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# ...

# %%
from pulp import LpVariable, LpProblem, lpSum, LpMinimize, GLPK, LpStatus

data = df.copy()

# Extract unique athletes and apparatus
athletes = set(data['Name'])
apparatus = set(data['Apparatus'])

# Create LP problem
model = LpProblem("Athlete_Score_Optimization", LpMinimize)

# Create binary decision variables
x = LpVariable.dicts('x', ((athlete, app) for athlete in athletes for app in apparatus), cat='Binary')

# Define the objective function
model += lpSum(data.loc[(data['Name'] == athlete) & (data['Apparatus'] == app), 'Score'] * x[athlete, app]
              for athlete in athletes for app in apparatus
              if not data.loc[(data['Name'] == athlete) & (data['Apparatus'] == app)].empty)

for app in apparatus:
    model += lpSum(x[athlete, app] for athlete in athletes) == 3  # Each apparatus is used exactly 3 times

model += lpSum(x[athlete, app] for athlete in athletes for app in apparatus) == 4  # Select exactly 4 athletes


# Define the constraints
for athlete in athletes:
    model += lpSum(x[athlete, app] for app in apparatus) == 1  # Each athlete competes on exactly 1 apparatus

# Solve the problem using GLPK solver
model.solve(GLPK(msg=True))

print("Solver Status:", LpStatus[model.status])

# Extract the results
selected_athletes = [athlete for athlete in athletes if any(x[athlete, app].value() > 0.9 for app in apparatus)]

# Display the results
print(f"Selected Athletes: {selected_athletes}")
print("Optimal Score:", model.objective.value())
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/2a2d9d6015114b42b9a527a26a3c6c22-pulp.lp
#  -o /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/2a2d9d6015114b42b9a527a26a3c6c22-pulp.sol
# Reading problem data from '/var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/2a2d9d6015114b42b9a527a26a3c6c22-pulp.lp'...
# 14 rows, 40 columns, 120 non-zeros
# 40 integer variables, all of which are binary
# 124 lines were read
# GLPK Integer Optimizer 5.0
# 14 rows, 40 columns, 120 non-zeros
# 40 integer variables, all of which are binary
# Preprocessing...
# 14 rows, 40 columns, 120 non-zeros
# 40 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 12
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# ...
